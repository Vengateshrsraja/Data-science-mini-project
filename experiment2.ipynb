# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df =pd.read_csv(r"Test.csv")

# %%
print(df)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %%
# convert csv to json file
import pandas as pd
df=pd.read_csv("Test.csv")
json_data=df.to_json(orient='records')
with open('Test.csv','w') as f:
  f.write(json_data)

# %%
import json
with open('Test.csv','w') as f:
  json.dump(json_data,f)

# %%
df1=pd.read_json("Test1.json")
print(df1)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %%
df2= pd.read_excel("Test2.xlsx")
print(df2)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2627 non-null   int64
#  1   Gender           2627 non-null   object
#  2   Ever_Married     2577 non-null   object
#  3   Age              2627 non-null   int64
#  4   Graduated        2603 non-null   object
#  5   Profession       2589 non-null   object
#  6   Work_Experience  2358 non-null   float64
#  7   Spending_Score   2627 non-null   object
#  8   Family_Size      2514 non-null   float64
#  9   Var_1            2595 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 205.4+ KB
#                   ID          Age  Work_Experience  Family_Size
# count    2627.000000  2627.000000      2358.000000  2514.000000
# mean   463433.918919    43.649791         2.552587     2.825378
# std      2618.245698    16.967015         3.341094     1.551906
# min    458989.000000    18.000000         0.000000     1.000000
# 25%    461162.500000    30.000000         0.000000     2.000000
# 50%    463379.000000    41.000000         1.000000     2.000000
# 75%    465696.000000    53.000000         4.000000     4.000000
# max    467968.000000    89.000000        14.000000     9.000000

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Graduated'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
plt.plot(df['Gender'],df['Spending_Score'])
plt.show()

# %%
df2.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    2627.000000  2627.000000      2358.000000  2514.000000
# mean   463433.918919    43.649791         2.552587     2.825378
# std      2618.245698    16.967015         3.341094     1.551906
# min    458989.000000    18.000000         0.000000     1.000000
# 25%    461162.500000    30.000000         0.000000     2.000000
# 50%    463379.000000    41.000000         1.000000     2.000000
# 75%    465696.000000    53.000000         4.000000     4.000000
# max    467968.000000    89.000000        14.000000     9.000000

# %%
df2['ID'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2622    False
# 2623    False
# 2624    False
# 2625    False
# 2626    False
# Name: ID, Length: 2627, dtype: bool

# %%
print(df2)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %%
print(df2['ID'])
# Out:
# 0       458989
# 1       458994
# 2       458996
# 3       459000
# 4       459001
#          ...
# 2622    467954
# 2623    467958
# 2624    467960
# 2625    467961
# 2626    467968
# Name: ID, Length: 2627, dtype: int64

# %%
df2[df2['ID'] >= 466564]
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 2226  466564  Female           No   18        No      Marketing
# 2227  466565    Male          Yes   32        No         Artist
# 2228  466576  Female           No   18        No     Healthcare
# 2229  466586    Male           No   18        No     Healthcare
# 2230  466588  Female           No   21        No     Healthcare
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 2226              1.0            Low          4.0  Cat_6
# 2227              7.0        Average          2.0  Cat_6
# 2228              0.0            Low          4.0  Cat_6
# 2229              0.0            Low          2.0  Cat_6
# 2230              8.0            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [401 rows x 10 columns]

# %%
df2.corr()
# Out:
#                        ID       Age  Work_Experience  Family_Size
# ID               1.000000 -0.022940        -0.025445     0.020830
# Age             -0.022940  1.000000        -0.186238    -0.285237
# Work_Experience -0.025445 -0.186238         1.000000    -0.071253
# Family_Size      0.020830 -0.285237        -0.071253     1.000000

# %%
plt.hist(df2['Family_Size'])
plt.show()

# %%
print(df1)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %%
print(df1['Profession'])
# Out:
# 0            Engineer
# 1          Healthcare
# 2
# 3           Executive
# 4           Marketing
#             ...
# 2622       Healthcare
# 2623           Doctor
# 2624    Entertainment
# 2625        Executive
# 2626       Healthcare
# Name: Profession, Length: 2627, dtype: object
